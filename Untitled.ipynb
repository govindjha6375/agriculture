# %%
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Handle table-like data and matrices
import numpy as np
import pandas as pd
import math 
# Modelling Algorithms
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier , GradientBoostingClassifier
from sklearn.metrics import accuracy_score

# Modelling Helpers
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFECV

# Visualisation
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

# Configure visualisations
# %matplotlib inline
mpl.style.use( 'ggplot' )
sns.set_style( 'white' )
pylab.rcParams[ 'figure.figsize' ] = 8 , 6

# %%
train = pd.read_csv("total (1).csv")
df = train

# %%
df.head()
# Out:
#     timestamp  state district     market               commodity  \
# 0  1523025126  Assam  Barpeta  Bohorihat  Black Gram (Urd Beans)
# 1  1523025126  Assam  Barpeta  Bohorihat         Corriander seed
# 2  1523025126  Assam  Barpeta  Bohorihat                    Jute
# 3  1523025126  Assam  Barpeta  Bohorihat           Lentil(Masur)
# 4  1523025126  Assam  Barpeta  Bohorihat                 Mustard
#
#               variety arrival_date  min_price  max_price  modal_price
# 0  Black Gram (Whole)   06/04/2018     2800.0     3000.0       2900.0
# 1      Coriander Seed   06/04/2018     3500.0     4000.0       3825.0
# 2                TD-5   06/04/2018     3200.0     3875.0       3825.0
# 3         Masoor Gola   06/04/2018     3400.0     3600.0       3500.0
# 4             Mustard   06/04/2018     3550.0     3650.0       3600.0

# %%
df.describe()
# Out:
#           timestamp     min_price      max_price    modal_price
# count  7.418000e+03   7418.000000    7418.000000    7418.000000
# mean   1.523025e+09   2551.547816    2999.163084    2804.140783
# std    4.987461e-01   3563.042575    4199.273121    3917.043677
# min    1.523025e+09      0.000000       0.000000       0.410000
# 25%    1.523025e+09    900.000000    1100.000000    1000.000000
# 50%    1.523025e+09   1650.000000    2000.000000    1828.500000
# 75%    1.523025e+09   3200.000000    3650.000000    3500.000000
# max    1.523025e+09  95000.000000  110000.000000  100000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7418 entries, 0 to 7417
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     7418 non-null   int64
#  1   state         7418 non-null   object
#  2   district      7418 non-null   object
#  3   market        7418 non-null   object
#  4   commodity     7418 non-null   object
#  5   variety       7418 non-null   object
#  6   arrival_date  7418 non-null   object
#  7   min_price     7418 non-null   float64
#  8   max_price     7418 non-null   float64
#  9   modal_price   7418 non-null   float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 579.7+ KB

# %%
df.shape
# Out:
# (7418, 10)

# %%
df.columns
# Out:
# Index(['timestamp', 'state', 'district', 'market', 'commodity', 'variety',
#        'arrival_date', 'min_price', 'max_price', 'modal_price'],
#       dtype='object')

# %%
# Out:
# (7418, 10)

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file="output.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ###generating dataset report which contain all the info abt data

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
newdf = df.select_dtypes(include=numerics)       #  numeric dataframe
objects = ['O']
df_o = df.select_dtypes(include=objects)

# %%
newdf.columns               #  numeric columns
# Out:
# Index(['timestamp', 'min_price', 'max_price', 'modal_price'], dtype='object')

# %%
df_o.columns                 #  categorical columns
# Out:
# Index(['state', 'district', 'market', 'commodity', 'variety', 'arrival_date'], dtype='object')

# %%
pd.crosstab([df.state], [df.commodity], margins=True).style.background_gradient(cmap='autumn_r')
# Out:
# <style type="text/css">
# #T_c43e8_row0_col0, #T_c43e8_row0_col1, #T_c43e8_row0_col2, #T_c43e8_row0_col3, #T_c43e8_row0_col4, #T_c43e8_row0_col5, #T_c43e8_row0_col6, #T_c43e8_row0_col7, #T_c43e8_row0_col8, #T_c43e8_row0_col9, #T_c43e8_row0_col10, #T_c43e8_row0_col11, #T_c43e8_row0_col12, #T_c43e8_row0_col13, #T_c43e8_row0_col14, #T_c43e8_row0_col15, #T_c43e8_row0_col16, #T_c43e8_row0_col17, #T_c43e8_row0_col18, #T_c43e8_row0_col19, #T_c43e8_row0_col20, #T_c43e8_row0_col22, #T_c43e8_row0_col23, #T_c43e8_row0_col24, #T_c43e8_row0_col25, #T_c43e8_row0_col26, #T_c43e8_row0_col27, #T_c43e8_row0_col28, #T_c43e8_row0_col29, #T_c43e8_row0_col30, #T_c43e8_row0_col31, #T_c43e8_row0_col32, #T_c43e8_row0_col33, #T_c43e8_row0_col34, #T_c43e8_row0_col35, #T_c43e8_row0_col36, #T_c43e8_row0_col37, #T_c43e8_row0_col38, #T_c43e8_row0_col39, #T_c43e8_row0_col40, #T_c43e8_row0_col41, #T_c43e8_row0_col42, #T_c43e8_row0_col43, #T_c43e8_row0_col44, #T_c43e8_row0_col45, #T_c43e8_row0_col46, #T_c43e8_row0_col47, #T_c43e8_row0_col48, #T_c43e8_row0_col49, #T_c43e8_row0_col51, #T_c43e8_row0_col52, #T_c43e8_row0_col53, #T_c43e8_row0_col54, #T_c43e8_row0_col55, #T_c43e8_row0_col56, #T_c43e8_row0_col57, #T_c43e8_row0_col58, #T_c43e8_row0_col59, #T_c43e8_row0_col60, #T_c43e8_row0_col61, #T_c43e8_row0_col62, #T_c43e8_row0_col63, #T_c43e8_row0_col64, #T_c43e8_row0_col65, #T_c43e8_row0_col66, #T_c43e8_row0_col67, #T_c43e8_row0_col68, #T_c43e8_row0_col69, #T_c43e8_row0_col70, #T_c43e8_row0_col71, #T_c43e8_row0_col72, #T_c43e8_row0_col73, #T_c43e8_row0_col74, #T_c43e8_row0_col76, #T_c43e8_row0_col78, #T_c43e8_row0_col79, #T_c43e8_row0_col80, #T_c43e8_row0_col81, #T_c43e8_row0_col82, #T_c43e8_row0_col83, #T_c43e8_row0_col84, #T_c43e8_row0_col85, #T_c43e8_row0_col86, #T_c43e8_row0_col87, #T_c43e8_row0_col88, #T_c43e8_row0_col89, #T_c43e8_row0_col90, #T_c43e8_row0_col91, #T_c43e8_row0_col92, #T_c43e8_row0_col94, #T_c43e8_row0_col95, #T_c43e8_row0_col96, #T_c43e8_row0_col97, #T_c43e8_row0_col98, #T_c43e8_row0_col99, #T_c43e8_row0_col100, #T_c43e8_row0_col101, #T_c43e8_row0_col103, #T_c43e8_row0_col104, #T_c43e8_row0_col105, #T_c43e8_row0_col106, #T_c43e8_row0_col107, #T_c43e8_row0_col108, #T_c43e8_row0_col109, #T_c43e8_row0_col111, #T_c43e8_row0_col112, #T_c43e8_row0_col113, #T_c43e8_row0_col114, #T_c43e8_row0_col115, #T_c43e8_row0_col116, #T_c43e8_row0_col117, #T_c43e8_row0_col118, #T_c43e8_row0_col119, #T_c43e8_row0_col120, #T_c43e8_row0_col121, #T_c43e8_row0_col122, #T_c43e8_row0_col123, #T_c43e8_row0_col124, #T_c43e8_row0_col126, #T_c43e8_row0_col127, #T_c43e8_row0_col128, #T_c43e8_row0_col129, #T_c43e8_row0_col130, #T_c43e8_row0_col131, #T_c43e8_row0_col132, #T_c43e8_row0_col133, #T_c43e8_row0_col134, #T_c43e8_row0_col135, #T_c43e8_row0_col136, #T_c43e8_row0_col137, #T_c43e8_row0_col138, #T_c43e8_row0_col139, #T_c43e8_row0_col140, #T_c43e8_row0_col141, #T_c43e8_row0_col142, #T_c43e8_row0_col143, #T_c43e8_row0_col144, #T_c43e8_row0_col145, #T_c43e8_row0_col147, #T_c43e8_row0_col148, #T_c43e8_row0_col149, #T_c43e8_row0_col150, #T_c43e8_row0_col151, #T_c43e8_row0_col152, #T_c43e8_row0_col153, #T_c43e8_row0_col154, #T_c43e8_row0_col155, #T_c43e8_row0_col156, #T_c43e8_row0_col157, #T_c43e8_row0_col158, #T_c43e8_row0_col159, #T_c43e8_row0_col160, #T_c43e8_row0_col161, #T_c43e8_row0_col162, #T_c43e8_row0_col163, #T_c43e8_row0_col164, #T_c43e8_row0_col165, #T_c43e8_row0_col166, #T_c43e8_row0_col167, #T_c43e8_row0_col168, #T_c43e8_row0_col169, #T_c43e8_row0_col170, #T_c43e8_row0_col171, #T_c43e8_row0_col172, #T_c43e8_row0_col173, #T_c43e8_row0_col174, #T_c43e8_row0_col175, #T_c43e8_row0_col176, #T_c43e8_row0_col177, #T_c43e8_row0_col178, #T_c43e8_row0_col179, #T_c43e8_row0_col180, #T_c43e8_row0_col181, #T_c43e8_row0_col182, #T_c43e8_row0_col183, #T_c43e8_row0_col184, #T_c43e8_row0_col185, #T_c43e8_row0_col186, #T_c43e8_row0_col187, #T_c43e8_row0_col189, #T_c43e8_row0_col190, #T_c43e8_row0_col191, #T_c43e8_row0_col192, #T_c43e8_row1_col0, #T_c43e8_row1_col1, #T_c43e8_row1_col2, #T_c43e8_row1_col3, ...

# %%
gp = df.loc[(df.state == "Rajasthan") & (df.district == "Ajmer") , : ]

# %%
a = ""
for i in range(0 , gp.shape[0]):
    a = a + gp.commodity + "    " + gp.variety + "    " + gp.arrival_date + "    " + str(gp.min_price) + "    " + str(gp.max_price) + "    " + str(gp.modal_price) + "    "

# %%
a
# Out:
# 4136    Bajra(Pearl Millet/Cumbu)    Other    06/04/20...
# 4137    Barley (Jau)    Other    06/04/2018    4136   ...
# 4138    Guar    Other    06/04/2018    4136    1100.0\...
# 4139    Mustard    Other    06/04/2018    4136    1100...
# 4140    Barley (Jau)    Other    06/04/2018    4136   ...
# 4141    Bengal Gram(Gram)    Other    06/04/2018    41...
# 4142    Cotton    American    06/04/2018    4136    11...
# 4143    Mustard    Other    06/04/2018    4136    1100...
# 4144    Wheat    Other    06/04/2018    4136    1100.0...
# dtype: object

# %%
gp
# Out:
#        timestamp      state district       market                  commodity  \
# 4136  1523025127  Rajasthan    Ajmer       Beawar  Bajra(Pearl Millet/Cumbu)
# 4137  1523025127  Rajasthan    Ajmer       Beawar               Barley (Jau)
# 4138  1523025127  Rajasthan    Ajmer       Beawar                       Guar
# 4139  1523025127  Rajasthan    Ajmer       Beawar                    Mustard
# 4140  1523025127  Rajasthan    Ajmer  Bijay Nagar               Barley (Jau)
# 4141  1523025127  Rajasthan    Ajmer  Bijay Nagar          Bengal Gram(Gram)
# 4142  1523025127  Rajasthan    Ajmer  Bijay Nagar                     Cotton
# 4143  1523025127  Rajasthan    Ajmer  Bijay Nagar                    Mustard
# 4144  1523025127  Rajasthan    Ajmer  Bijay Nagar                      Wheat
#
#        variety arrival_date  min_price  max_price  modal_price
# 4136     Other   06/04/2018     1100.0     1200.0       1150.0
# 4137     Other   06/04/2018     1300.0     1350.0       1325.0
# 4138     Other   06/04/2018     3700.0     3850.0       3775.0
# 4139     Other   06/04/2018     3400.0     3550.0       3475.0
# 4140     Other   06/04/2018     1281.0     1300.0       1290.0
# 4141     Other   06/04/2018     2602.0     3550.0       3500.0
# 4142  American   06/04/2018     4856.0     5150.0       5000.0
# 4143     Other   06/04/2018     3375.0     3452.0       3400.0
# 4144     Other   06/04/2018     1250.0     1800.0       1700.0

# %%
def get_graphs(state , district , market):
    gp = df.loc[(df.state == state) & (df.district == district) & (df.market == market), : ]
    fig, axes = plt.subplots(5,1)
    fig.set_size_inches(20, 30)
    sns.barplot(data=gp ,y="modal_price",x="commodity", hue = "variety" ,orient="v" ,ax=axes[0] )
    sns.kdeplot(gp.modal_price , shade=True, color="r" , ax=axes[1] )
    sns.stripplot(x="commodity", y="modal_price", data=gp , hue = "variety" , jitter=True , ax = axes[2])
    sns.distplot(gp.modal_price , ax = axes[3])
    sns.pointplot(x="commodity", y="modal_price", data=gp , ax = axes[4] ) 
    fig.savefig("2.png")

# %%
get_graphs("Kerala" , "Alappuzha" , "Aroor")

# %%
 def pairplot(state , district , market):
    gp = df.loc[(df.state == state) & (df.district == district) & (df.market == market), : ]
    g = sns.PairGrid(gp , hue = "variety")
    g = g.map_diag(plt.hist)
    g = g.map_offdiag(plt.scatter)
    g = g.add_legend()
    g = plt.figure(figsize=(15,10))
    fig.savefig("4.png")

# %%
pairplot("Uttar Pradesh" , "Agra" , "Achnera")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 pairplot("Uttar Pradesh" , "Agra" , "Achnera")
#
# Cell In[24], line 8, in pairplot(state, district, market)
#       6 g = g.add_legend()
#       7 g = plt.figure(figsize=(15,10))
# ----> 8 fig.savefig("4.png")
#
# NameError: name 'fig' is not defined

# %%
sns.pairplot(gp , hue = "variety")

# %%
sns.jointplot(x="min_price", y="modal_price", data=gp , kind="reg")

# %%
g = sns.jointplot(x="max_price", y="modal_price", data=gp , kind="reg")

# %%
g = sns.jointplot(x="min_price", y="max_price", data=gp , kind="reg")

# %%
temp = df.loc[(df.state == "Uttar Pradesh") & (df.district == "Agra") & (df.commodity == "Potato"), : ]
temp
# Out:
#        timestamp          state district          market commodity variety  \
# 4718  1523025127  Uttar Pradesh     Agra         Achnera    Potato    Desi
# 4752  1523025127  Uttar Pradesh     Agra            Agra    Potato    Desi
# 4771  1523025127  Uttar Pradesh     Agra  Fatehpur Sikri    Potato   Local
# 4791  1523025127  Uttar Pradesh     Agra         Jagnair    Potato    Desi
# 4811  1523025127  Uttar Pradesh     Agra           Jarar    Potato    Desi
# 4835  1523025127  Uttar Pradesh     Agra      Khairagarh    Potato    Desi
#
#      arrival_date  min_price  max_price  modal_price
# 4718   06/04/2018      840.0      860.0        850.0
# 4752   06/04/2018      850.0      980.0        910.0
# 4771   06/04/2018      800.0      940.0        870.0
# 4791   06/04/2018      840.0      860.0        850.0
# 4811   06/04/2018      600.0      800.0        700.0
# 4835   06/04/2018      840.0      860.0        850.0

# %%
def get_val(state , district , commodity):
    temp = df.loc[(df.state == state) & (df.district == district) & (df.commodity == commodity), : ]
    fig, axes = plt.subplots(6,1)
    fig.set_size_inches(20, 30)
    sns.barplot(data=temp ,y="min_price",x="market" ,orient="v" , ax = axes[0] )
    sns.pointplot(data=temp ,y="min_price",x="market" ,orient="v" , ax = axes[1] )
    #sns.stripplot(x="market", y="min_price", data=temp , jitter=True ,  ax = axes[1])
    #sns.distplot(temp.modal_price , ax = axes[3])
    sns.barplot(data=temp ,y="modal_price",x="market" ,orient="v" , ax = axes[2] )
    sns.pointplot(data=temp ,y="modal_price",x="market" ,orient="v" , ax = axes[3] )
    sns.barplot(data=temp ,y="max_price",x="market" ,orient="v" , ax = axes[4] )
    sns.pointplot(data=temp ,y="max_price",x="market" ,orient="v" , ax = axes[5] )
    fig.savefig("3.png")

# %%
get_val("Uttar Pradesh" , "Agra" , "Brinjal")

# %%
df.head()
# Out:
#     timestamp  state district     market               commodity  \
# 0  1523025126  Assam  Barpeta  Bohorihat  Black Gram (Urd Beans)
# 1  1523025126  Assam  Barpeta  Bohorihat         Corriander seed
# 2  1523025126  Assam  Barpeta  Bohorihat                    Jute
# 3  1523025126  Assam  Barpeta  Bohorihat           Lentil(Masur)
# 4  1523025126  Assam  Barpeta  Bohorihat                 Mustard
#
#               variety arrival_date  min_price  max_price  modal_price
# 0  Black Gram (Whole)   06/04/2018     2800.0     3000.0       2900.0
# 1      Coriander Seed   06/04/2018     3500.0     4000.0       3825.0
# 2                TD-5   06/04/2018     3200.0     3875.0       3825.0
# 3         Masoor Gola   06/04/2018     3400.0     3600.0       3500.0
# 4             Mustard   06/04/2018     3550.0     3650.0       3600.0

# %%
df.groupby(['state' , 'commodity']).mean(numeric_only=True)
# Out:
#                                            timestamp    min_price  \
# state       commodity
# Assam       Black Gram (Urd Beans)      1.523025e+09  2800.000000
#             Corriander seed             1.523025e+09  3500.000000
#             Green Chilli                1.523025e+09  1500.000000
#             Green Gram Dal (Moong Dal)  1.523025e+09  6200.000000
#             Jute                        1.523025e+09  3266.666667
# ...                                              ...          ...
# West Bengal Ridgeguard(Tori)            1.523025e+09  2500.000000
#             Sugar                       1.523025e+09  3700.000000
#             Sweet Pumpkin               1.523025e+09   842.857143
#             Tomato                      1.523025e+09   633.888889
#             Wheat                       1.523025e+09  1626.250000
#
#                                           max_price  modal_price
# state       commodity
# Assam       Black Gram (Urd Beans)      3000.000000  2900.000000
#             Corriander seed             4000.000000  3825.000000
#             Green Chilli                2000.000000  1800.000000
#             Green Gram Dal (Moong Dal)  7000.000000  6600.000000
#             Jute                        3758.333333  3708.333333
# ...                                             ...          ...
# West Bengal Ridgeguard(Tori)            2725.000000  2625.000000
#             Sugar                       3750.000000  3720.000000
#             Sweet Pumpkin               1042.857143   942.857143
#             Tomato                       818.333333   725.000000
#             Wheat                       1695.000000  1658.750000
#
# [820 rows x 4 columns]
